# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scienceplots
import matplotlib

print(matplotlib.get_configdir())

df=pd.read_excel('tmp_files/hbm1_size.xlsx')
print(df.head())

# 设置图表样式
with plt.style.context(['science', 'grid','vibrant']):

    # 准备x轴数据（Epoch）
    hbm_sizes = [str(size) for size in df['HBM Size'].values]

    # 创建1行4列的子图，调整figsize以适应新布局
    fig, axes = plt.subplots(1, 4, figsize=(12, 3))

    # MSLS数据
    axes[0].plot(hbm_sizes, df['Nordland R@1'], 'o-', label='R@1')
    axes[0].plot(hbm_sizes, df['Nordland R@5'], 's-', label='R@5')
    axes[0].plot(hbm_sizes, df['Nordland R@10'], '^-', label='R@10')
    axes[0].set_title('Nordland')
    axes[0].legend(frameon=False)
    axes[0].set_xlabel('HBM Size')
    axes[0].set_ylabel('Recall (\\%)')
    axes[0].set_xticks(hbm_sizes)

    # Nordland数据
    axes[1].plot(hbm_sizes, df['SVOX Night R@1'], 'o-', label='R@1')
    axes[1].plot(hbm_sizes, df['SVOX Night R@5'], 's-', label='R@5')
    axes[1].plot(hbm_sizes, df['SVOX Night R@10'], '^-', label='R@10')
    axes[1].set_title('SVOX Night')
    axes[1].legend(frameon=False)
    axes[1].set_xlabel('HBM Size')
    axes[1].set_ylabel('Recall (\\%)')
    axes[1].set_xticks(hbm_sizes)

    # Pitts数据
    axes[2].plot(hbm_sizes, df['SVOX Rain R@1'], 'o-', label='R@1')
    axes[2].plot(hbm_sizes, df['SVOX Rain R@5'], 's-', label='R@5')
    axes[2].plot(hbm_sizes, df['SVOX Rain R@10'], '^-', label='R@10')
    axes[2].set_title('SVOX Rain')
    axes[2].legend(frameon=False)
    axes[2].set_xlabel('HBM Size')
    axes[2].set_ylabel('Recall (\\%)')
    axes[2].set_xticks(hbm_sizes)

    # Tokyo24/7数据
    axes[3].plot(hbm_sizes, df['Amster Time R@1'], 'o-', label='R@1')
    axes[3].plot(hbm_sizes, df['Amster Time R@5'], 's-', label='R@5')
    axes[3].plot(hbm_sizes, df['Amster Time R@10'], '^-', label='R@10')
    axes[3].set_title('Amster Time')
    axes[3].legend(frameon=False)
    axes[3].set_xlabel('HBM Size')
    axes[3].set_ylabel('Recall (\\%)')
    axes[3].set_xticks(hbm_sizes)

    # 调整子图之间的间距
    plt.tight_layout()
    plt.savefig('images/hbm_size.png',dpi=600)
    # 显示图表
    plt.show()
# Out:
# /home/cartolab3/.config/matplotlib
#    HBM Size  Nordland R@1  Nordland R@5  Nordland R@10  Eynsham R@1  \
# 0       256         94.47         98.43          99.23        91.45
# 1       512         95.06         98.55          99.17        91.52
# 2      1024         95.11         98.65          99.20        91.50
# 3      2048         95.21         98.70          99.25        91.71
# 4      4096         95.66         98.79          99.40        91.75
#
#    Eynsham R@5  Eynsham R@10  SVOX Night R@1  SVOX Night R@5  SVOX Night R@10  \
# 0        95.29         96.19           89.43           96.60            98.18
# 1        95.19         96.21           90.77           96.96            98.06
# 2        95.43         96.35           91.74           97.08            98.42
# 3        95.31         96.23           93.92           97.57            99.15
# 4        95.30         96.21           93.07           97.81            98.91
#
#    SVOX Rain R@1  SVOX Rain R@5  SVOX Rain R@10  Amster Time R@1  \
# 0          95.41          98.51           99.15            50.28
# 1          96.26          98.93           99.47            54.02
# 2          96.26          99.04           99.25            53.21
# 3          97.23          99.25           99.47            52.64
# 4          97.44          99.36           99.47            53.05
#
#    Amster Time R@5  Amster Time R@10
# 0            73.60             79.69
# 1            75.55             81.97
# 2            75.87             82.70
# 3            75.47             80.99
# 4            74.33             79.69
